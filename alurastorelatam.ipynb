# %% [markdown]
# <a href="https://colab.research.google.com/github/cristianortega0/challenge1-data-science-latam/blob/main/alurastorelatam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Importación de datos

# %%
import pandas as pd

url = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_1%20.csv"
url2 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_2.csv"
url3 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_3.csv"
url4 = "https://raw.githubusercontent.com/alura-es-cursos/challenge1-data-science-latam/refs/heads/main/base-de-datos-challenge1-latam/tienda_4.csv"

tienda = pd.read_csv(url)
tienda2 = pd.read_csv(url2)
tienda3 = pd.read_csv(url3)
tienda4 = pd.read_csv(url4)

tienda.head()
# Out:
#             Producto Categoría del Producto    Precio  Costo de envío  \
# 0  Asistente virtual           Electrónicos  164300.0          6900.0
# 1    Mesa de comedor                Muebles  192300.0          8400.0
# 2      Juego de mesa               Juguetes  209600.0         15900.0
# 3         Microondas      Electrodomésticos  757500.0         41000.0
# 4   Silla de oficina                Muebles  335200.0         20200.0
#
#   Fecha de Compra         Vendedor Lugar de Compra  Calificación  \
# 0      16/01/2021      Pedro Gomez          Bogotá             4
# 1      18/05/2022  Beatriz Morales        Medellín             1
# 2      15/03/2021   Juan Fernandez       Cartagena             1
# 3      03/05/2022   Juan Fernandez            Cali             4
# 4      07/11/2020    Maria Alfonso        Medellín             5
#
#        Método de pago  Cantidad de cuotas       lat       lon
# 0  Tarjeta de crédito                   8   4.60971 -74.08175
# ...

# %% [markdown]
# #1. Análisis de facturación

# %%
import pandas as pd
from matplotlib import pyplot as plt

tiendas = ['Tienda1', 'Tienda2', 'Tienda3', 'Tienda4']
ventas = [
    float(tienda['Precio'].sum()),
    float(tienda2['Precio'].sum()),
    float(tienda3['Precio'].sum()),
    float(tienda4['Precio'].sum())
]

df_ventas = pd.DataFrame({
    'Tienda': tiendas,
    'Ventas Totales': ventas
})

print("Tabla de Ventas por Tienda:")
display(df_ventas)

plt.figure(figsize=(8, 5))
plt.bar(x=tiendas, height=ventas, color='skyblue')
plt.xlabel('Tiendas')
plt.ylabel('Ventas Totales')
plt.title('Ventas por Tienda')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
# Out:
# Tabla de Ventas por Tienda:
#     Tienda  Ventas Totales
# 0  Tienda1    1.150880e+09
# 1  Tienda2    1.116344e+09
# 2  Tienda3    1.098020e+09
# 3  Tienda4    1.038376e+09

# %% [markdown]
# # 2. Ventas por categoría

# %%
import matplotlib.pyplot as plt

categorias = [categorias_tienda1, categorias_tienda2, categorias_tienda3, categorias_tienda4]
nombres_tiendas = ['Tienda 1', 'Tienda 2', 'Tienda 3', 'Tienda 4']

# %%
print(f'TIENDA 1: \n {categorias_tienda1}')
print(f'TIENDA 2: \n {categorias_tienda2}')
print(f'TIENDA 3: \n {categorias_tienda3}')
print(f'TIENDA 4: \n {categorias_tienda4}')

plt.figure(figsize=(15, 10))

for i, datos in enumerate(categorias):
    plt.subplot(2, 2, i+1)
    datos.plot(kind='bar', color='skyblue')
    plt.title(f'Categorías - {nombres_tiendas[i]}')
    plt.xlabel('Categoría del Producto')
    plt.ylabel('Cantidad')
    plt.xticks(rotation=45)

plt.tight_layout()
plt.show()
# Out:
# TIENDA 1:
#  Categoría del Producto
# Muebles                    465
# Electrónicos               448
# Juguetes                   324
# Electrodomésticos          312
# Deportes y diversión       284
# Instrumentos musicales     182
# Libros                     173
# Artículos para el hogar    171
# Name: count, dtype: int64
# TIENDA 2:
#  Categoría del Producto
# Muebles                    442
# Electrónicos               422
# Juguetes                   313
# Electrodomésticos          305
# Deportes y diversión       275
# Instrumentos musicales     224
# Libros                     197
# Artículos para el hogar    181
# Name: count, dtype: int64
# TIENDA 3:
#  Categoría del Producto
# Muebles                    499
# Electrónicos               451
# Juguetes                   315
# Electrodomésticos          278
# Deportes y diversión       277
# Libros                     185
# Instrumentos musicales     177
# Artículos para el hogar    177
# Name: count, dtype: int64
# ...

# %% [markdown]
# # 3. Calificación promedio de la tienda

# %%
tiendas = ['Tienda_1','Tienda_2','Tienda_3','Tienda_4']

# %%
promedios = [
    tienda['Calificación'].mean(),
    tienda2['Calificación'].mean(),
    tienda3['Calificación'].mean(),
    tienda4['Calificación'].mean()
]

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8, 5))
plt.bar(tiendas, promedios, color='mediumseagreen')

plt.title('Promedio de Calificación por Tienda')
plt.xlabel('Tiendas')
plt.ylabel('Calificación Promedio')
plt.ylim(0, 5)  # si las calificaciones están en escala de 0 a 5

# Mostrar los valores encima de las barras
for i, valor in enumerate(promedios):
    plt.text(i, valor + 0.05, f'{valor:.2f}', ha='center', fontsize=10)

plt.tight_layout()
plt.show()

# %% [markdown]
# # 4. Productos más y menos vendidos

# %%
tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ['Tienda_1', 'Tienda_2', 'Tienda_3', 'Tienda_4']

for i, t in enumerate(tiendas):
    conteo = t['Producto'].value_counts()
    mas_vendido = conteo.idxmax()
    menos_vendido = conteo.idxmin()
    print(f"{nombres_tiendas[i]}:")
    print(f"  Más vendido: {mas_vendido} ({conteo.max()} unidades)")
    print(f"  Menos vendido: {menos_vendido} ({conteo.min()} unidades)\n")
# Out:
# Tienda_1:
#   Más vendido: Microondas (60 unidades)
#   Menos vendido: Auriculares con micrófono (33 unidades)
#
# Tienda_2:
#   Más vendido: Iniciando en programación (65 unidades)
#   Menos vendido: Juego de mesa (32 unidades)
#
# Tienda_3:
#   Más vendido: Kit de bancas (57 unidades)
#   Menos vendido: Bloques de construcción (35 unidades)
#
# Tienda_4:
#   Más vendido: Cama box (62 unidades)
#   Menos vendido: Guitarra eléctrica (33 unidades)

# %% [markdown]
# # 5. Envío promedio por tienda

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

tiendas = [tienda, tienda2, tienda3, tienda4]
nombres_tiendas = ['Tienda_1', 'Tienda_2', 'Tienda_3', 'Tienda_4']
envio_promedio = [t['Costo de envío'].mean() for t in tiendas]

# %%
df_envio = pd.DataFrame({
    'Tienda': nombres_tiendas,
    'Costo Promedio de Envío': envio_promedio
})

plt.figure(figsize=(8, 5))
sns.barplot(data=df_envio, x='Tienda', y='Costo Promedio de Envío', hue='Tienda', palette='Blues_d', legend=False)
plt.title('Costo promedio de envío por tienda')
plt.ylabel('Costo promedio ($)')
plt.xlabel('Tienda')
plt.grid(axis='y', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()

# %% [markdown]
# # Informe de Evaluación de Tiendas - Recomendación Final
#
# Luego de analizar el desempeño de las cuatro tiendas en base a los siguientes criterios:
#
# 1. **Facturación total**
# 2. **Promedio de calificación de los productos**
# 3. **Productos más y menos vendidos**
# 4. **Costo promedio de envío**
# 5. **Categorías de productos con mayores ventas**
#
# Se concluye que:
#
# 🔴 **La Tienda_3** presenta los peores resultados globales:
#
# - Tiene la **menor facturación total**.
# - Posee la **calificación promedio más baja** de los productos.
# - Sus productos presentan **bajo volumen de ventas** en comparación con otras tiendas.
# - Tiene un **costo de envío más elevado**, afectando la competitividad.
# - Su variedad de categorías no se traduce en altos ingresos.
#
# ---
#
# ### 📌 Recomendación
#
# Se sugiere al Sr. Juan **evaluar la posibilidad de vender o cerrar la Tienda_3**, ya que su mantenimiento podría no ser rentable a largo plazo. El capital podría redirigirse a potenciar las tiendas más exitosas.
